# %% [markdown]
# # Newton vs the Machine
#
# <div>
# <img src="img/initial_pos.png" width="500"/>
# </div>
# <div>
# <img src="img/mlp.png" width="600"/>
# </div>
#
# #### $$(t, x_2(0), y_2(0)) \longrightarrow
# (x_1(t), y_1(t), x_2(t), y_2(t), v^x_1(t), v^y_1(t), v^x_2(t), v^y_2(t), v^x_3(t), v^y_3(t)) $$

# %%
from energy import main as energy_main
from energy import *
from vis import *
# %matplotlib inline

# %%
figsize = (10, 10)
i = 3
files = [f"./samples/solution_000{i:03}.pkl", f"./samples/solution_000{i:03}-model.pkl"]
solutions = [load_data(f) for f in files]

# %%
SolutionAnimation([solutions[0]], figsize=figsize).run().to_html()
# Out:
# <video width="1000" height="1000" controls autoplay>
#   <source type="video/mp4" src="...

# %%
SolutionAnimation(solutions, figsize=figsize).run().to_html()
# Out:
# <video width="1000" height="1000" controls autoplay>
#   <source type="video/mp4" src="...

# %%
energy_main(files)

# %%
figsize = (10, 10)
i = 34
files = [f"./samples/solution_000{i:03}.pkl", f"./samples/solution_000{i:03}-model.pkl"]
solutions = [load_data(f) for f in files]

# %%
SolutionAnimation([solutions[0]], figsize=figsize).run().to_html()
# Out:
# <video width="1000" height="1000" controls autoplay>
#   <source type="video/mp4" src="...

# %%
SolutionAnimation(solutions, figsize=figsize).run().to_html()
# Out:
# <video width="1000" height="1000" controls autoplay>
#   <source type="video/mp4" src="...

# %%
energy_main(files)
